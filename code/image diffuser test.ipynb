# %%
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler #hugging face stable diffuser default code
import torch
model_id = "stabilityai/stable-diffusion-2"
scheduler = EulerDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")
pipe = StableDiffusionPipeline.from_pretrained(model_id, scheduler=scheduler, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "a photo of an astronaut riding a horse on mars"
image = pipe(prompt).images[0]
# Out:
# vae\diffusion_pytorch_model.safetensors not found
# ...
# 100%|██████████| 50/50 [00:21<00:00,  2.28it/s]

# %%
print("Torch version:",torch.__version__)

print("Is CUDA enabled?",torch.cuda.is_available())
# Out:
# Torch version: 2.1.0+cu118
# Is CUDA enabled? True

# %%
from PIL import Image

# %%
image = pipe('red dragon named embercleave').images[0]
# Out:
# 100%|██████████| 50/50 [00:17<00:00,  2.89it/s]

# %%
image = image.resize((469, 348))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=469x348>

# %%
img1 = Image.open('redcreature.png')

# %%
img1.show()

# %%
img1.paste(image, (50,93))

# %%
img1.show()
